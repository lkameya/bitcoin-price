# %%
import math
from sklearn.preprocessing import StandardScaler
from sklearn import model_selection, metrics
from sklearn import preprocessing, cross_validation, svm

import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, KFold, cross_val_score, cross_val_predict

import matplotlib.pyplot as plt
from matplotlib import style
import datetime

style.use('ggplot')

df = pd.read_csv("BCHARTS-MRCDBRL.csv")

df.shape
# Out:
# C:\Users\leonardo.kameya\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# (2601, 8)

# %%
df.head()
# Out:
#          Date         Open     High      Low        Close  Volume (BTC)  \
# 0  2018-09-09  26531.20000  27600.0  26309.0  26900.00000     53.213124
# 1  2018-09-08  27379.77889  27380.0  26500.0  26531.00023     55.077662
# 2  2018-09-07  27775.00001  27910.0  27101.0  27222.10000     63.637533
# 3  2018-09-06  28300.00000  29000.0  26850.0  27775.00001    248.240788
# 4  2018-09-05  30799.00000  30998.0  28300.0  28300.00000    250.949612
#
#    Volume (Currency)  Weighted Price
# 0       1.439447e+06    27050.605696
# 1       1.483940e+06    26942.686125
# 2       1.747844e+06    27465.616803
# 3       6.793996e+06    27368.572275
# 4       7.425127e+06    29588.121067

# %%
df.describe()
# Out:
#                Open          High           Low         Close  Volume (BTC)  \
# count   2601.000000   2601.000000   2601.000000   2601.000000   2601.000000
# mean    5570.233151   5758.754098   5341.700691   5581.309698    130.236809
# std    10937.259599  11339.771027  10424.305383  10946.282566    174.664282
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%      200.100000    212.400000    191.000010    200.011100     31.459066
# 50%     1170.130170   1210.000000   1131.000010   1170.000000     83.178696
# 75%     2721.040040   2756.825070   2652.540000   2723.300790    155.498332
# max    69350.000000  69950.000000  66650.000000  69350.000000   2580.039441
#
#        Volume (Currency)  Weighted Price
# count       2.601000e+03     2601.000000
# mean        1.669668e+06     5566.877797
# std         6.320334e+06    10911.524571
# min         0.000000e+00        0.000000
# 25%         4.653615e+03      203.375137
# ...

# %%
df.isnull().values.any()
# Out:
# False

# %%
X = pd.DataFrame(df, columns=['Open', 'High', 'Low', 'Close', 'Volume (BTC)', 'Volume (Currency)'])

X = np.array(X)

y = np.array(df['Weighted Price'])

lm = LinearRegression(n_jobs=-1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

model = lm.fit(X_train, y_train)

predictions = lm.predict(X_test)

confidence = lm.score(X_test, y_test)

print(confidence)

plt.legend(loc=4)
plt.title("Valores previstos", size=10)
plt.scatter(y_test, predictions, color='c', marker='.')
plt.xlabel("Valor atual", size=10)
plt.ylabel("Valor Previsto", size=10)
plt.show()
# Out:
# No handles with labels found to put in legend.
# 0.9998719327605576

# %%
plt.legend(loc=4)
plt.title("Homogeinidade da Variancia")
plt.scatter(y_test, y_test-predictions)
plt.xlabel("Atual")
plt.ylabel("Residual")
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
scores = cross_val_score(model, X, y, cv=10)
print("Cross Validated Scores", scores)
kf = KFold(n_splits=10, random_state=None, shuffle=True)
for train_index, test_index in kf.split(X):
    print("TRAIN", train_index, "TEST", test_index)
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

# Make cross validated predictions
predictions2 = cross_val_predict(model, X, y, cv=10)

#Check the R2 - proportion of variance in the dependent variable explained by the predictors

accuracy = metrics.r2_score(y, predictions2)

print("R2: ", accuracy)

plt.scatter(y, predictions2, color='c', marker='.')
plt.legend(loc=4)
plt.xlabel("Atual", size=10)
plt.ylabel("Previsto", size=10)
plt.title("Atual e previsto", size=10)
plt.show()
# Out:
# No handles with labels found to put in legend.
# Cross Validated Scores [0.99326105 0.99821516 0.99879988 0.99740311 0.9970819  0.9988054
#  0.99780796 0.99793369 0.49599372 0.49257033]
# TRAIN [   0    1    2 ... 2597 2598 2600] TEST [  16   20   29   42   55   74   80   81   84   86   90   97   99  115
#   116  147  161  193  194  197  205  208  240  248  252  260  264  283
#   297  302  319  320  323  334  351  367  376  379  380  383  394  411
#   428  429  433  436  439  442  443  451  463  465  466  500  544  566
#   571  575  577  579  582  609  616  617  625  627  651  671  675  678
#   692  697  704  716  733  737  769  783  791  803  806  811  823  836
#   837  838  842  849  854  859  868  869  873  875  881  889  898  902
#   908  915  916  918  930  931  934  935  941  968  980  994 1005 1023
#  1032 1035 1056 1077 1098 1099 1109 1111 1114 1128 1130 1135 1155 1163
#  1191 1195 1206 1217 1218 1219 1223 1230 1238 1273 1284 1293 1315 1340
# ...

# %%
import quandl

df = quandl.get('BCHARTS/MRCDBRL')

df
# Out:
#                    Open         High          Low        Close  Volume (BTC)  \
# Date
# 2011-07-28     23.99000     23.99000     23.99000     23.99000      2.000000
# 2011-07-29     23.49000     23.50000     23.49000     23.50000      8.000000
# 2011-07-30     23.49000     23.49000     23.40000     23.40000      2.000000
# 2011-07-31     23.49000     23.50000     23.49000     23.50000      8.500000
# 2011-08-01     23.40000     23.40000     23.25000     23.25000      3.000000
# 2011-08-02      0.00000      0.00000      0.00000      0.00000      0.000000
# 2011-08-03      0.00000      0.00000      0.00000      0.00000      0.000000
# 2011-08-04      0.00000      0.00000      0.00000      0.00000      0.000000
# 2011-08-05      0.00000      0.00000      0.00000      0.00000      0.000000
# 2011-08-06     18.95000     18.95000     18.95000     18.95000      5.500000
# 2011-08-07      0.00000      0.00000      0.00000      0.00000      0.000000
# ...

# %%
df

forecast_out = int(30) # predicting 30 days into future

df['Prediction'] = df[['Weighted Price']].shift(-forecast_out)

df
# Out:
#                    Open         High          Low        Close  Volume (BTC)  \
# Date
# 2011-07-28     23.99000     23.99000     23.99000     23.99000      2.000000
# 2011-07-29     23.49000     23.50000     23.49000     23.50000      8.000000
# 2011-07-30     23.49000     23.49000     23.40000     23.40000      2.000000
# 2011-07-31     23.49000     23.50000     23.49000     23.50000      8.500000
# 2011-08-01     23.40000     23.40000     23.25000     23.25000      3.000000
# 2011-08-02      0.00000      0.00000      0.00000      0.00000      0.000000
# 2011-08-03      0.00000      0.00000      0.00000      0.00000      0.000000
# 2011-08-04      0.00000      0.00000      0.00000      0.00000      0.000000
# 2011-08-05      0.00000      0.00000      0.00000      0.00000      0.000000
# 2011-08-06     18.95000     18.95000     18.95000     18.95000      5.500000
# 2011-08-07      0.00000      0.00000      0.00000      0.00000      0.000000
# ...

# %%
#X = np.array(df.drop(['Prediction'], 1))
X = pd.DataFrame(df, columns=['Open', 'High', 'Low', 'Close', 'Volume (BTC)', 'Volume (Currency)'])
X = preprocessing.scale(X)

X_forecast = X[-forecast_out:] # set X_forecast ultimos 30
X = X[:-forecast_out] #remove ultimos 30 dias de X

y = np.array(df['Prediction'])
y = y[:-forecast_out]

X_train, X_test, y_train, y_test = cross_validation.train_test_split(X, y, test_size=0.2)

# %%
# Treinando

clf = LinearRegression()
clf.fit(X_train, y_train)

#Testando
confidence = clf.score(X_test, y_test)
print("confidence: ", confidence)
# Out:
# confidence:  0.8762650165267323

# %%
forecast_prediction = clf.predict(X_forecast)
print(forecast_prediction)
# Out:
# [23098.98811813 23073.11269892 23712.96754354 23982.6348595
#  23890.86595123 24259.83415567 23741.76807325 23859.46495473
#  24044.97275069 24535.78282211 23888.27760818 24595.93132977
#  25429.03972464 25081.26990388 24637.18134908 26156.46785758
#  27818.79246786 27487.70153549 26990.57746316 27268.34907178
#  26998.37459031 27030.58952349 28849.11077457 29266.64671383
#  25822.93896187 26216.37443721 25024.01341109 24209.4550315
#  24810.70349761 24151.40188808]
# [1.85122587e+01 1.82343802e+01 1.66588235e+01 ... 2.69426861e+04
#  2.70476134e+04 2.65787827e+04]
